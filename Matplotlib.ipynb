# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
x.shape
# Out:
# (11,)

# %%
plt.plot(x, y, 'b')
plt.xlabel('wind speed')
plt.ylabel('power output')
plt.title('Visualization')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-');

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8]) #left, bottom, widht, height (range 0 to 1)

axes.plot(x,y,'b')
axes.set_xlabel('set X label')
axes.set_ylabel('set Y label')
axes.set_title('Graph')
# Out:
# Text(0.5, 1.0, 'Graph')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) #left, bottom, widht, height (range 0 to 1)
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y,'b')
axes1.set_xlabel('set X label1')
axes1.set_ylabel('set Y label1')
axes1.set_title('Graph1')


axes2.plot(x,y,'g')
axes2.set_xlabel('set X label2')
axes2.set_ylabel('set Y label2')
axes2.set_title('Graph2');

# %% [markdown]
# subplots()

# %%
fig, axes = plt.subplots()

axes.plot(x,y,'r*-')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('Graph');

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
for ax in axes:
    ax.plot(x,y,"b")
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_title("title")

# %%
fig

# %%
fig, axes=plt.subplots(nrows=1,ncols=2)
for ax in axes:
    ax.plot(x,y,"g")
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_title("title")

fig
plt.tight_layout()

# %%
fig=plt.figure(figsize=(0,4),dpi=100)

# %%
fig, axes= plt.subplots(figsize=(12,3))

axes.plot(x,y,"r")
axes.set_xlabel("X")
axes.set_ylabel("Y")
axes.set_title("title");

# %%
fig, axes= plt.subplots(figsize=(12,3))

axes.plot(y,x,"r")
axes.set_xlabel("X")
axes.set_ylabel("Y")
axes.set_title("title");

# %%
fig.savefig("image1.png",dpi=1000)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])

ax.plot(x,x**2,label="x**2",color="red")
ax.plot(x,x**3,label="x**3",color="green")
ax.legend();

# %%
ax.legend(loc=1) #upper right corner
ax.legend(loc=2) #upper left corner
ax.legend(loc=3) #lower left corner
ax.legend(loc=4) #lower right corner

ax.legend(loc=0) #let matplotlib decide the optimal location
fig

# %%
fig, ax=plt.subplots()
ax.plot(x,x**2,"b.-")
ax.plot(x,x**3,"g--");

# %%
fig, ax = plt.subplots()
ax.plot(x,x+1,color="blue",alpha=0.5)
ax.plot(x,x+2,color="#8B008B")
ax.plot(x,x+3,color="#FF8C00");

# %%
fig,ax=plt.subplots(figsize=(12,6))

ax.plot(x,x+1,color="red",lw=0.25)
ax.plot(x,x+2,color="red",lw=0.50)
ax.plot(x,x+3,color="red",lw=1.00)
ax.plot(x,x+4,color="red",lw=2.00)

ax.plot(x,x+5,color="green",lw=3,ls="-")
ax.plot(x,x+6,color="green",lw=3,ls="-")
ax.plot(x,x+7,color="green",lw=3,ls=":")

line,=ax.plot(x,x+8,color="black",lw=1.5)
line.set_dashes([5,10,15,10])

ax.plot(x,x+9,color="blue",lw=3,ls="-",marker="+")
ax.plot(x,x+10,color="blue",lw=3,ls="--",marker="o")
ax.plot(x,x+11,color="blue",lw=3,ls="-",marker="s")
ax.plot(x,x+12,color="blue",lw=3,ls="--",marker="1")

ax.plot(x,x+13,color="purple",lw=1,ls="-",marker="o",markersize=2)
ax.plot(x,x+14,color="purple",lw=1,ls="-",marker="o",markersize=4)
ax.plot(x,x+15,color="purple",lw=1,ls="-",marker="o",markersize=6,markerfacecolor="red")
ax.plot(x,x+16,color="purple",lw=1,ls="-",marker="s",markersize=8,markerfacecolor="yellow",markeredgewidth=3,markeredgecolor="green");

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title('tight axes')

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range")
# Out:
# Text(0.5, 1.0, 'custom axes range')

# %% [markdown]
# special plot types

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,x**2);

# %%
plt.scatter(y**2, y**3)

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].scatter( x**2,  x**3)
axes[0].set_title("default axes ranges")

axes[1].scatter( x**2,  x**3)
axes[1].axis('tight')
axes[1].set_title('tight axes')

axes[2].scatter( x**2,  x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([5, 10])
axes[2].set_title("custom axes range")
# Out:
# Text(0.5, 1.0, 'custom axes range')

# %% [markdown]
# Histogram

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([10., 11., 13.,  9., 10., 13.,  8.,  8., 10.,  8.]),
#  array([  4. , 103.1, 202.2, 301.3, 400.4, 499.5, 598.6, 697.7, 796.8,
#         895.9, 995. ]),
#  <BarContainer object of 10 artists>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1,4)]

plt.boxplot(data,vert=True,patch_artist=True);

# %%
data=[[30,25,50,20],[40,23,51,17],[35,22,45,19]]
x=np.arange(4)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.bar(x+0.00,data[0],color="b",width=0.25)
ax.bar(x+0.25,data[1],color="g",width=0.25)
ax.bar(x+0.50,data[2],color="r",width=0.25);
